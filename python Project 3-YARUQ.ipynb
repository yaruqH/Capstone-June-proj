# %%
# Saving data and uploading to Jupytre NB.
# Analysis of the NYPD Arrest Data Year To Date open data.



import pandas as pd

# %%
# Here u will search to see if the dataset exported from the NYC OpenData, i save download and saved.

df=pd.read_csv('C:/Users/Yhassan/Downloads/NYPD_Arrest_Data__Year_to_Date__20240505.csv')

# %%
#display results to see columns and data

df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   280255493  01/10/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1   279805419  01/02/2024  157.0                          RAPE 1  104.0
# 2   279895750  01/03/2024  101.0                       ASSAULT 3  344.0
# 3   280809090  01/19/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 4   280357135  01/11/2024  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                       ROBBERY  PL 1601001          F           M
# 1                          RAPE  PL 1303501          F           K
# 2  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           Q
# 3               DANGEROUS DRUGS  PL 2200300          M           B
# 4                FELONY ASSAULT  PL 1200502          F           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# ...

# %%
# Here i Start to see the data analysis  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63621 entries, 0 to 63620
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ARREST_KEY                63621 non-null  int64
#  1   ARREST_DATE               63621 non-null  object
#  2   PD_CD                     63619 non-null  float64
#  3   PD_DESC                   63621 non-null  object
#  4   KY_CD                     63612 non-null  float64
#  5   OFNS_DESC                 63621 non-null  object
#  6   LAW_CODE                  63621 non-null  object
#  7   LAW_CAT_CD                63219 non-null  object
#  8   ARREST_BORO               63621 non-null  object
#  9   ARREST_PRECINCT           63621 non-null  int64
#  10  JURISDICTION_CODE         63621 non-null  int64
#  11  AGE_GROUP                 63621 non-null  object
#  12  PERP_SEX                  63621 non-null  object
# ...

# %%
df.tail()
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 63616   282877412  02/27/2024  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 63617   283628088  03/12/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 63618   283387006  03/07/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 63619   283013910  03/01/2024  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 63620   283495531  03/10/2024  203.0            TRESPASS 3, CRIMINAL  352.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 63616             PETIT LARCENY  PL 1552500          M           K
# 63617           DANGEROUS DRUGS  PL 2200300          M           M
# 63618                   ROBBERY  PL 160102A          F           K
# 63619  VEHICLE AND TRAFFIC LAWS  VTL05110A4          M           K
# 63620         CRIMINAL TRESPASS  PL 140100A          M           S
#
#        ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# ...

# %%
# Check on missing values

missing_values=df.isnull().sum()

# %%
# code: here pop up the missing values
missing_values
# Out:
# ARREST_KEY                    0
# ARREST_DATE                   0
# PD_CD                         2
# PD_DESC                       0
# KY_CD                         9
# OFNS_DESC                     0
# LAW_CODE                      0
# LAW_CAT_CD                  402
# ARREST_BORO                   0
# ARREST_PRECINCT               0
# JURISDICTION_CODE             0
# AGE_GROUP                     0
# PERP_SEX                      0
# PERP_RACE                     0
# X_COORD_CD                    0
# Y_COORD_CD                    0
# Latitude                      0
# Longitude                     0
# New Georeferenced Column      0
# dtype: int64

# %%
unique_values=df.nunique()

# %%
# here checking all the columns value
unique_values
# Out:
# ARREST_KEY                  63621
# ARREST_DATE                    91
# PD_CD                         231
# PD_DESC                       221
# KY_CD                          66
# OFNS_DESC                      62
# LAW_CODE                      770
# LAW_CAT_CD                      6
# ARREST_BORO                     5
# ARREST_PRECINCT                77
# JURISDICTION_CODE              25
# AGE_GROUP                       5
# PERP_SEX                        2
# PERP_RACE                       7
# X_COORD_CD                  15785
# Y_COORD_CD                  16393
# Latitude                    17663
# Longitude                   17629
# New Georeferenced Column    17879
# dtype: int64

# %%
# viewing the data types
df.dtypes
# Out:
# ARREST_KEY                    int64
# ARREST_DATE                  object
# PD_CD                       float64
# PD_DESC                      object
# KY_CD                       float64
# OFNS_DESC                    object
# LAW_CODE                     object
# LAW_CAT_CD                   object
# ARREST_BORO                  object
# ARREST_PRECINCT               int64
# JURISDICTION_CODE             int64
# AGE_GROUP                    object
# PERP_SEX                     object
# PERP_RACE                    object
# X_COORD_CD                    int64
# Y_COORD_CD                    int64
# Latitude                    float64
# Longitude                   float64
# New Georeferenced Column     object
# dtype: object

# %%
#Cleanup

# Here i will be checking which columns i will keep for my dataframe
columns_to_keep=['ARREST_KEY','ARREST_DATE','PD_DESC','ARREST_BORO','AGE_GROUP','PERP_SEX','PERP_RACE']

# %%
#Subset # code to ensure the column i selected will be in my dataframe
subset_df=df[columns_to_keep]

# %%
#  Here code to see if the column i select display in my dataset

subset_df.head()
# Out:
#    ARREST_KEY ARREST_DATE                         PD_DESC ARREST_BORO  \
# 0   280255493  01/10/2024  ROBBERY,OPEN AREA UNCLASSIFIED           M
# 1   279805419  01/02/2024                          RAPE 1           K
# 2   279895750  01/03/2024                       ASSAULT 3           Q
# 3   280809090  01/19/2024  CONTROLLED SUBSTANCE, POSSESSI           B
# 4   280357135  01/11/2024        ASSAULT 2,1,UNCLASSIFIED           K
#
#   AGE_GROUP PERP_SEX       PERP_RACE
# 0       <18        M           BLACK
# 1     25-44        M  WHITE HISPANIC
# 2       65+        F           WHITE
# 3     45-64        M           BLACK
# 4     25-44        F           BLACK

# %%
# Here some descriptive analysis (descriptive statistics)
df.min
# Out:
# <bound method DataFrame.min of        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       280255493  01/10/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1       279805419  01/02/2024  157.0                          RAPE 1  104.0
# 2       279895750  01/03/2024  101.0                       ASSAULT 3  344.0
# 3       280809090  01/19/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 4       280357135  01/11/2024  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
# ...           ...         ...    ...                             ...    ...
# 63616   282877412  02/27/2024  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 63617   283628088  03/12/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 63618   283387006  03/07/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 63619   283013910  03/01/2024  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 63620   283495531  03/10/2024  203.0            TRESPASS 3, CRIMINAL  352.0
#
# ...

# %%
# Here i was exploring Data Analysis (EDA) on the subset dataframe
subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63621 entries, 0 to 63620
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ARREST_KEY   63621 non-null  int64
#  1   ARREST_DATE  63621 non-null  object
#  2   PD_DESC      63621 non-null  object
#  3   ARREST_BORO  63621 non-null  object
#  4   AGE_GROUP    63621 non-null  object
#  5   PERP_SEX     63621 non-null  object
#  6   PERP_RACE    63621 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 3.4+ MB

# %%
#Checking to see the missing values, to ensure only displaying the selected columns i select

missing_values=subset_df.isnull().sum

# %%
missing_values()
# Out:
# ARREST_KEY     0
# ARREST_DATE    0
# PD_DESC        0
# ARREST_BORO    0
# AGE_GROUP      0
# PERP_SEX       0
# PERP_RACE      0
# dtype: int64

# %%
# here i was checking to see using the (df.head) the first few rows of the dataset, many sure that i displaying the selected columns

subset_df.head()
# Out:
#    ARREST_KEY ARREST_DATE                         PD_DESC ARREST_BORO  \
# 0   280255493  01/10/2024  ROBBERY,OPEN AREA UNCLASSIFIED           M
# 1   279805419  01/02/2024                          RAPE 1           K
# 2   279895750  01/03/2024                       ASSAULT 3           Q
# 3   280809090  01/19/2024  CONTROLLED SUBSTANCE, POSSESSI           B
# 4   280357135  01/11/2024        ASSAULT 2,1,UNCLASSIFIED           K
#
#   AGE_GROUP PERP_SEX       PERP_RACE
# 0       <18        M           BLACK
# 1     25-44        M  WHITE HISPANIC
# 2       65+        F           WHITE
# 3     45-64        M           BLACK
# 4     25-44        F           BLACK

# %%
# checking all the my data name
df.columns
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'],
#       dtype='object')

# %%
# there 63621 row and 19 columns

df.shape
# Out:
# (63621, 19)

# %%
#  Now i will search to see what are the value of the 'Unknown' value
subset_df['ARREST_KEY'].unique()
# Out:
# array([280255493, 279805419, 279895750, ..., 283387006, 283013910,
#        283495531], dtype=int64)

# %%
subset_df['ARREST_DATE'].unique()
# Out:
# array(['01/10/2024', '01/02/2024', '01/03/2024', '01/19/2024',
#        '01/11/2024', '02/01/2024', '01/30/2024', '01/23/2024',
#        '01/31/2024', '02/03/2024', '01/26/2024', '02/07/2024',
#        '02/02/2024', '02/15/2024', '02/20/2024', '02/19/2024',
#        '02/29/2024', '03/16/2024', '03/04/2024', '03/18/2024',
#        '03/06/2024', '01/08/2024', '01/13/2024', '01/22/2024',
#        '01/28/2024', '01/27/2024', '01/29/2024', '01/12/2024',
#        '01/25/2024', '01/01/2024', '01/09/2024', '01/24/2024',
#        '01/17/2024', '01/20/2024', '01/04/2024', '01/05/2024',
#        '01/06/2024', '01/15/2024', '01/14/2024', '01/21/2024',
#        '01/18/2024', '01/07/2024', '02/08/2024', '02/05/2024',
#        '02/06/2024', '01/16/2024', '02/10/2024', '02/04/2024',
#        '02/16/2024', '02/09/2024', '02/11/2024', '02/13/2024',
#        '02/12/2024', '02/18/2024', '02/14/2024', '02/17/2024',
#        '02/25/2024', '03/03/2024', '03/12/2024', '02/24/2024',
# ...

# %%
subset_df['PD_DESC'].unique()
# Out:
# array(['ROBBERY,OPEN AREA UNCLASSIFIED', 'RAPE 1', 'ASSAULT 3',
#        'CONTROLLED SUBSTANCE, POSSESSI', 'ASSAULT 2,1,UNCLASSIFIED',
#        'JOSTLING', '(null)', 'RAPE 2', 'STRANGULATION 1ST', 'ARSON 2,3,4',
#        'BURGLARY,UNCLASSIFIED,UNKNOWN', 'ROBBERY,CAR JACKING', 'RAPE 3',
#        'WEAPONS POSSESSION 3', 'RECKLESS ENDANGERMENT 1',
#        'TRAFFIC,UNCLASSIFIED MISDEMEAN', 'LARCENY,PETIT FROM OPEN AREAS,',
#        'TRESPASS 3, CRIMINAL', 'LARCENY,GRAND FROM PERSON,UNCL',
#        'THEFT OF SERVICES, UNCLASSIFIE', 'CONTROLLED SUBSTANCE,SALE 3',
#        'MENACING,UNCLASSIFIED', 'LARCENY,GRAND OF AUTO',
#        'CRIMINAL MIS 2 & 3', 'LEWDNESS,PUBLIC',
#        'CRIMINAL MISCHIEF,UNCLASSIFIED 4', 'OBSTR BREATH/CIRCUL',
#        'TRAFFIC,UNCLASSIFIED INFRACTIO', 'PUBLIC ADMINISTATION,UNCLASS M',
#        'WEAPONS, POSSESSION, ETC', 'DISORDERLY CONDUCT',
#        'CHILD, ENDANGERING WELFARE', 'CRIMINAL CONTEMPT 1',
# ...

# %%
subset_df['ARREST_BORO'].unique()
# Out:
# array(['M', 'K', 'Q', 'B', 'S'], dtype=object)

# %%
subset_df['AGE_GROUP'].unique()
# Out:
# array(['<18', '25-44', '65+', '45-64', '18-24'], dtype=object)

# %%
subset_df['PERP_SEX'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
subset_df['PERP_RACE'].unique()
# Out:
# array(['BLACK', 'WHITE HISPANIC', 'WHITE', 'ASIAN / PACIFIC ISLANDER',
#        'UNKNOWN', 'BLACK HISPANIC', 'AMERICAN INDIAN/ALASKAN NATIVE'],
#       dtype=object)

# %%
#Checking the Data Type

subset_df.dtypes
# Out:
# ARREST_KEY      int64
# ARREST_DATE    object
# PD_DESC        object
# ARREST_BORO    object
# AGE_GROUP      object
# PERP_SEX       object
# PERP_RACE      object
# dtype: object

# %%
# will define the unknown values
unwanted_values=['?','Unknown', 'Unknown/Invalid']

# %%
subset_df=subset_df[~subset_df['ARREST_KEY'].isin(unwanted_values)]

# %%
subset_df=subset_df[~subset_df['ARREST_DATE'].isin(unwanted_values)]

# %%
subset_df.reset_index(drop=True, inplace=True)

# %%
subset_df
# Out:
#        ARREST_KEY ARREST_DATE                         PD_DESC ARREST_BORO  \
# 0       280255493  01/10/2024  ROBBERY,OPEN AREA UNCLASSIFIED           M
# 1       279805419  01/02/2024                          RAPE 1           K
# 2       279895750  01/03/2024                       ASSAULT 3           Q
# 3       280809090  01/19/2024  CONTROLLED SUBSTANCE, POSSESSI           B
# 4       280357135  01/11/2024        ASSAULT 2,1,UNCLASSIFIED           K
# ...           ...         ...                             ...         ...
# 63616   282877412  02/27/2024  LARCENY,PETIT FROM OPEN AREAS,           K
# 63617   283628088  03/12/2024  CONTROLLED SUBSTANCE, POSSESSI           M
# 63618   283387006  03/07/2024  ROBBERY,OPEN AREA UNCLASSIFIED           K
# 63619   283013910  03/01/2024  TRAFFIC,UNCLASSIFIED MISDEMEAN           K
# 63620   283495531  03/10/2024            TRESPASS 3, CRIMINAL           S
#
#       AGE_GROUP PERP_SEX       PERP_RACE
# ...

# %%
# now i will categorical columns to category data type
subset_df['PERP_RACE']=subset_df['PERP_RACE'].astype('category')

# %%
subset_df['ARREST_BORO']=subset_df['ARREST_BORO'].astype('category')

# %%
subset_df['PD_DESC']=subset_df['PD_DESC'].astype('category')

# %%
# Checking the Data type making sure  the update was complete
subset_df.dtypes
# Out:
# ARREST_KEY        int64
# ARREST_DATE      object
# PD_DESC        category
# ARREST_BORO    category
# AGE_GROUP        object
# PERP_SEX         object
# PERP_RACE      category
# dtype: object

# %%
# Doing group by ''
race_grouped=subset_df.groupby('PERP_RACE').size()

# %%
# Doing some data search to be able to do my comparising.
# Checking to see which race has been arrested the most. As far i can see, BLACK and white hispanic.

race_grouped
# Out:
# PERP_RACE
# AMERICAN INDIAN/ALASKAN NATIVE      185
# ASIAN / PACIFIC ISLANDER           3543
# BLACK                             29466
# BLACK HISPANIC                     6336
# UNKNOWN                             293
# WHITE                              6607
# WHITE HISPANIC                    17191
# dtype: int64

# %%
# checking the ARREST_BORO   to see what boro has more Arrest  # in the Borough of Brookly(k ) has the highest arrest 14221. State island as the least 2892. )
Boro_grouped=subset_df.groupby('ARREST_BORO').size()

# %%
Boro_grouped
# Out:
# ARREST_BORO
# B    14221
# K    17402
# M    15324
# Q    13782
# S     2892
# dtype: int64

# %%
#I Choose BLACK  race as the initial comparison point. They have the MOST arrest as race.

initial_comparison_group=subset_df[subset_df['PERP_RACE']=='BLACK']

# %%
# Here i notice that the age between 25-44 is the age_group that has been more arrested in the black race.
initial_comparison_group
# Out:
#        ARREST_KEY ARREST_DATE                         PD_DESC ARREST_BORO  \
# 0       280255493  01/10/2024  ROBBERY,OPEN AREA UNCLASSIFIED           M
# 3       280809090  01/19/2024  CONTROLLED SUBSTANCE, POSSESSI           B
# 4       280357135  01/11/2024        ASSAULT 2,1,UNCLASSIFIED           K
# 5       281488967  02/01/2024                          RAPE 1           Q
# 6       280769124  01/19/2024                        JOSTLING           M
# ...           ...         ...                             ...         ...
# 63612   283851888  03/16/2024  CONTROLLED SUBSTANCE, POSSESSI           M
# 63615   283436353  03/08/2024  FORGERY,ETC.,UNCLASSIFIED-FELO           K
# 63617   283628088  03/12/2024  CONTROLLED SUBSTANCE, POSSESSI           M
# 63618   283387006  03/07/2024  ROBBERY,OPEN AREA UNCLASSIFIED           K
# 63619   283013910  03/01/2024  TRAFFIC,UNCLASSIFIED MISDEMEAN           K
#
#       AGE_GROUP PERP_SEX PERP_RACE
# 0           <18        M     BLACK
# ...

# %%
#Checking the dataset to ensure only contains Black population info. There is 29466 people.
initial_comparison_group['PERP_RACE'].value_counts()
# Out:
# BLACK                             29466
# WHITE HISPANIC                        0
# WHITE                                 0
# UNKNOWN                               0
# BLACK HISPANIC                        0
# ASIAN / PACIFIC ISLANDER              0
# AMERICAN INDIAN/ALASKAN NATIVE        0
# Name: PERP_RACE, dtype: int64

# %%
 # Checking all the arrest based on Sex, Race, and Age Group. # There is more male arrested 52432.


grouped_arrest_sex=subset_df.groupby(['PERP_SEX']).size().reset_index(name='Counts')

# %%
# There is more male arrested 52432
grouped_arrest_sex
# Out:
#   PERP_SEX  Counts
# 0        F   11189
# 1        M   52432

# %%
# There is more black 29466.
grouped_arrest_race=subset_df.groupby(['PERP_RACE']).size().reset_index(name='Counts')

# %%
grouped_arrest_race
# Out:
#                         PERP_RACE  Counts
# 0  AMERICAN INDIAN/ALASKAN NATIVE     185
# 1        ASIAN / PACIFIC ISLANDER    3543
# 2                           BLACK   29466
# 3                  BLACK HISPANIC    6336
# 4                         UNKNOWN     293
# 5                           WHITE    6607
# 6                  WHITE HISPANIC   17191

# %%
# The 25-44 age is the more popular age group of people arrested.
grouped_arrest_age=subset_df.groupby(['AGE_GROUP']).size().reset_index(name='Counts')

# %%
grouped_arrest_age
# Out:
#   AGE_GROUP  Counts
# 0     18-24   10684
# 1     25-44   37254
# 2     45-64   12315
# 3       65+    1041
# 4       <18    2327

# %%
# In BKLYN(K) The age_group more popular of arrest is 25-44. AND most of the population is the Black race.

brooklyn_data=subset_df[subset_df['ARREST_BORO']=='K']

# %%
brooklyn_data
# Out:
#        ARREST_KEY ARREST_DATE                         PD_DESC ARREST_BORO  \
# 1       279805419  01/02/2024                          RAPE 1           K
# 4       280357135  01/11/2024        ASSAULT 2,1,UNCLASSIFIED           K
# 11      281422833  01/31/2024               STRANGULATION 1ST           K
# 12      281438374  01/31/2024                     ARSON 2,3,4           K
# 13      281179458  01/26/2024   BURGLARY,UNCLASSIFIED,UNKNOWN           K
# ...           ...         ...                             ...         ...
# 63602   282944832  02/28/2024  CONTROLLED SUBSTANCE, INTENT T           K
# 63615   283436353  03/08/2024  FORGERY,ETC.,UNCLASSIFIED-FELO           K
# 63616   282877412  02/27/2024  LARCENY,PETIT FROM OPEN AREAS,           K
# 63618   283387006  03/07/2024  ROBBERY,OPEN AREA UNCLASSIFIED           K
# 63619   283013910  03/01/2024  TRAFFIC,UNCLASSIFIED MISDEMEAN           K
#
#       AGE_GROUP PERP_SEX       PERP_RACE
# ...

# %%
# In brooklyn the count is 9732.
brooklyn_arrest_race=brooklyn_data.groupby(['PERP_RACE']).size().reset_index(name='Counts')

# %%
brooklyn_arrest_race
# Out:
#                         PERP_RACE  Counts
# 0  AMERICAN INDIAN/ALASKAN NATIVE      46
# 1        ASIAN / PACIFIC ISLANDER     844
# 2                           BLACK    9732
# 3                  BLACK HISPANIC     996
# 4                         UNKNOWN      49
# 5                           WHITE    2109
# 6                  WHITE HISPANIC    3626

# %%
# When i check by age in Brooklyn 24-44 is 10071.
brooklyn_arrest_age=brooklyn_data.groupby(['AGE_GROUP']).size().reset_index(name='Counts')

# %%
brooklyn_arrest_age
# Out:
#   AGE_GROUP  Counts
# 0     18-24    2889
# 1     25-44   10071
# 2     45-64    3454
# 3       65+     271
# 4       <18     717

# %%
# Checking by gender in Brooklyn  male it was 14376.
brooklyn_arrest_gender=brooklyn_data.groupby(['PERP_SEX']).size().reset_index(name='Counts')

# %%
brooklyn_arrest_gender
# Out:
#   PERP_SEX  Counts
# 0        F    3026
# 1        M   14376

# %%
#The comparison of the  Brooklyn cases, based on Race, Sex and Age Group . I notice there is also a unknown value. 

grouped_sex_race_counts=brooklyn_data.groupby(['PERP_RACE','PERP_SEX']).size().reset_index(name='Total_Count')

# %%
grouped_sex_race_counts
# Out:
#                          PERP_RACE PERP_SEX  Total_Count
# 0   AMERICAN INDIAN/ALASKAN NATIVE        F           10
# 1   AMERICAN INDIAN/ALASKAN NATIVE        M           36
# 2         ASIAN / PACIFIC ISLANDER        F          134
# 3         ASIAN / PACIFIC ISLANDER        M          710
# 4                            BLACK        F         1783
# 5                            BLACK        M         7949
# 6                   BLACK HISPANIC        F          124
# 7                   BLACK HISPANIC        M          872
# 8                          UNKNOWN        F            9
# 9                          UNKNOWN        M           40
# 10                           WHITE        F          404
# 11                           WHITE        M         1705
# 12                  WHITE HISPANIC        F          562
# 13                  WHITE HISPANIC        M         3064

# %%
# Here im doing the data by sex and age group, and calculate the total count for each
grouped_sex_age_counts=brooklyn_data.groupby(['PERP_SEX','AGE_GROUP']).size().reset_index(name='Total_Count')

# %%
grouped_sex_age_counts
# Out:
#   PERP_SEX AGE_GROUP  Total_Count
# 0        F     18-24          545
# 1        F     25-44         1773
# 2        F     45-64          551
# 3        F       65+           37
# 4        F       <18          120
# 5        M     18-24         2344
# 6        M     25-44         8298
# 7        M     45-64         2903
# 8        M       65+          234
# 9        M       <18          597

# %%
# I will start doing my Visualization.


import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Plot a stcked bar chart using Seaborn
plt.figure(figsize=(20,8))
sns.barplot(x='PERP_RACE',y='Total_Count',hue='PERP_SEX', data=grouped_sex_race_counts, palette='Set1')
plt.title('Distribution of Arrests by Sex and Race in Brooklyn')
plt.xlabel('Race and Sex')
plt.ylabel('Number of Arrests')
plt.xticks(rotation=60,ha='right')
plt.legend(title='Sex')
plt.tight_layout()
plt.show()

# %%
#Plot a stcked bar chart using Seaborn
plt.figure(figsize=(20,8))
sns.barplot(x='AGE_GROUP',y='Total_Count',hue='PERP_SEX', data=grouped_sex_age_counts, palette='Set1')
plt.title('Distribution of Arrests by Age Group and Sex in Brooklyn')
plt.xlabel('Sex and Age Group')
plt.ylabel('Number of Arrests')
plt.xticks(rotation=60,ha='right')
plt.legend(title='Sex')
plt.tight_layout()
plt.show()

# %%
#Majoriity Arrests for Males group 25-44 of in Black or White Hispanic race
# Most Arrests for Misdemeanor or Felony in BKLYN
